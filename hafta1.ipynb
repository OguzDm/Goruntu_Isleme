# %%
list_1 = [1,2,3,4,5]

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
catImage = plt.imread('7b9.jpg')

# %%
catImage
# Out:
# array([[[ 22,  22,  34],
#         [ 23,  21,  34],
#         [ 25,  19,  33],
#         ...,
#         [194, 191, 198],
#         [195, 192, 199],
#         [195, 192, 199]],
#
#        [[ 23,  21,  34],
#         [ 22,  20,  33],
#         [ 24,  18,  32],
#         ...,
#         [196, 193, 200],
#         [196, 193, 200],
#         [197, 194, 201]],
#
#        [[ 23,  20,  31],
#         [ 22,  19,  30],
#         [ 24,  18,  30],
#         ...,
#         [195, 196, 201],
#         [195, 196, 201],
#         [195, 196, 201]],
#
#        ...,
#
#        [[ 22,  17,  14],
#         [ 20,  15,  12],
#         [ 16,  10,  10],
#         ...,
#         [145, 144, 150],
#         [145, 144, 150],
#         [145, 144, 150]],
#
#        [[ 22,  17,  14],
#         [ 20,  15,  12],
#         [ 16,  10,  10],
#         ...,
#         [143, 142, 148],
#         [143, 142, 148],
#         [143, 142, 148]],
#
#        [[ 23,  18,  15],
#         [ 20,  15,  12],
#         [ 17,  11,  11],
# ...

# %%
type(catImage)
# Out:
# numpy.ndarray

# %%
catImage.shape
# Out:
# (326, 326, 3)

# %%
catImage[0,0,0]
# Out:
# 22

# %%
catImage[0,0,1]
# Out:
# 22

# %%
catImage[0,0,2]
# Out:
# 34

# %%
for row in range(5):
    for col in range(5):
        for rgb in range(3):
            print(catImage[row,col,rgb])
# Out:
# 22
# 22
# 34
# 23
# 21
# 34
# 25
# 19
# 33
# 25
# 17
# 32
# 27
# 14
# 31
# 23
# 21
# 34
# 22
# 20
# 33
# 24
# 18
# 32
# 24
# 16
# 31
# 27
# 14
# 31
# 23
# 20
# 31
# 22
# 19
# 30
# 24
# 18
# 30
# 24
# 16
# 29
# 25
# 14
# 28
# 21
# 18
# 29
# 23
# 17
# 29
# 23
# 17
# 29
# 24
# 16
# 29
# 24
# 16
# 29
# 22
# 14
# 27
# 23
# 15
# 28
# 23
# 17
# 29
# 24
# 18
# 30
# 24
# 18
# 30

# %%
plt.imshow(catImage)
plt.show()
